# %%
import pandas as pd
import pdmod1
### import imp
### imp.reload(pdmod1)

# %%
a = pdmod1.Class_1(".\csv\Sales Records.csv")
a.sort_1("Country").head(10)
# Out:
#                          Region      Country  Item Type Sales Channel  \
# 0  Middle East and North Africa  Afghanistan     Cereal       Offline
# 1  Middle East and North Africa  Afghanistan  Household       Offline
# 2  Middle East and North Africa  Afghanistan     Cereal       Offline
# 3  Middle East and North Africa  Afghanistan       Meat       Offline
# 4  Middle East and North Africa  Afghanistan  Household       Offline
# 5  Middle East and North Africa  Afghanistan  Cosmetics       Offline
# 6  Middle East and North Africa  Afghanistan  Household       Offline
# 7  Middle East and North Africa  Afghanistan     Snacks        Online
# 8  Middle East and North Africa  Afghanistan    Clothes        Online
# 9  Middle East and North Africa  Afghanistan     Snacks       Offline
#
#   Order Priority  Order Date   Order ID   Ship Date  Units Sold  Unit Price  \
# 0              H   7/24/2013  933963477   8/23/2013        9402      205.70
# ...

# %%
a.drop_1("Ship Date", 'Order ID', 'Sales Channel', 'Total Revenue').head(10)
# Out:
#                          Region      Country  Item Type Order Priority  \
# 0  Middle East and North Africa  Afghanistan     Cereal              H
# 1  Middle East and North Africa  Afghanistan  Household              L
# 2  Middle East and North Africa  Afghanistan     Cereal              H
# 3  Middle East and North Africa  Afghanistan       Meat              H
# 4  Middle East and North Africa  Afghanistan  Household              M
# 5  Middle East and North Africa  Afghanistan  Cosmetics              L
# 6  Middle East and North Africa  Afghanistan  Household              C
# 7  Middle East and North Africa  Afghanistan     Snacks              C
# 8  Middle East and North Africa  Afghanistan    Clothes              C
# 9  Middle East and North Africa  Afghanistan     Snacks              L
#
#    Order Date  Units Sold  Unit Price  Unit Cost  Total Cost  Total Profit
# 0   7/24/2013        9402      205.70     117.11  1101068.22     832923.18
# ...
