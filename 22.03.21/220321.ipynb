# %%
import yfinance as yf

# %%
yf.download('AAPL',start='2019-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-12-31   39.632500   39.840000   39.119999   39.435001   38.233891
# 2019-01-02   38.722500   39.712502   38.557499   39.480000   38.277523
# 2019-01-03   35.994999   36.430000   35.500000   35.547501   34.464798
# 2019-01-04   36.132500   37.137501   35.950001   37.064999   35.936081
# 2019-01-07   37.174999   37.207500   36.474998   36.982498   35.856087
# ...                ...         ...         ...         ...         ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  150.619995
# 2022-03-15  150.899994  155.570007  150.380005  155.089996  155.089996
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  159.589996
# 2022-03-17  158.610001  161.000000  157.630005  160.619995  160.619995
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  163.979996
#
#                Volume
# Date
# ...

# %%
data = yf.download(['AAPL', 'TSLA', 'AMZN'], start='2019-01-01')
data
# Out:
# [*********************100%***********************]  3 of 3 completed
#              Adj Close                                Close               \
#                   AAPL         AMZN        TSLA        AAPL         AMZN
# Date
# 2018-12-31   38.233898  1501.969971   66.559998   39.435001  1501.969971
# 2019-01-02   38.277523  1539.130005   62.023998   39.480000  1539.130005
# 2019-01-03   34.464802  1500.280029   60.071999   35.547501  1500.280029
# 2019-01-04   35.936077  1575.390015   63.537998   37.064999  1575.390015
# 2019-01-07   35.856091  1629.510010   66.991997   36.982498  1629.510010
# ...                ...          ...         ...         ...          ...
# 2022-03-14  150.619995  2837.060059  766.369995  150.619995  2837.060059
# 2022-03-15  155.089996  2947.330078  801.890015  155.089996  2947.330078
# 2022-03-16  159.589996  3062.080078  840.229980  159.589996  3062.080078
# 2022-03-17  160.619995  3144.780029  871.599976  160.619995  3144.780029
# ...

# %%
data['Close']['AAPL']
# Out:
# Date
# 2018-12-31     39.435001
# 2019-01-02     39.480000
# 2019-01-03     35.547501
# 2019-01-04     37.064999
# 2019-01-07     36.982498
#                  ...
# 2022-03-14    150.619995
# 2022-03-15    155.089996
# 2022-03-16    159.589996
# 2022-03-17    160.619995
# 2022-03-18    163.979996
# Name: AAPL, Length: 811, dtype: float64

# %%
aapl = yf.Ticker('AAPL')
aapl
# Out:
# yfinance.Ticker object <AAPL>

# %%
aapl.splits
# Out:
# Date
# 1987-06-16    2.0
# 2000-06-21    2.0
# 2005-02-28    2.0
# 2014-06-09    7.0
# 2020-08-31    4.0
# Name: Stock Splits, dtype: float64

# %%
aapl.recommendations
# Out:
#                                     Firm      To Grade From Grade Action
# Date
# 2012-02-09 08:17:00    Canaccord Genuity           Buy              main
# 2012-03-08 07:33:00       FBN Securities    Outperform              main
# 2012-03-13 06:08:00            Jefferies           Buy              main
# 2012-03-14 06:13:00       Morgan Stanley    Overweight              main
# 2012-03-14 08:21:00    Canaccord Genuity           Buy              main
# ...                                  ...           ...        ...    ...
# 2022-01-28 14:19:01  New Street Research       Neutral       Sell     up
# 2022-01-28 15:10:56          Oppenheimer    Outperform              main
# 2022-01-31 15:44:19        Credit Suisse       Neutral              main
# 2022-02-15 15:31:58    Tigress Financial    Strong Buy              main
# 2022-03-11 11:57:08             Barclays  Equal-Weight              main
#
# [831 rows x 4 columns]

# %%
aapl.info
# Out:
# {'zip': '95014',
#  'sector': 'Technology',
#  'fullTimeEmployees': 100000,
# ...

# %%
aapl.history(period='max')
# Out:
#                   Open        High         Low       Close     Volume  \
# Date
# 1980-12-12    0.100323    0.100759    0.100323    0.100323  469033600
# 1980-12-15    0.095525    0.095525    0.095089    0.095089  175884800
# 1980-12-16    0.088546    0.088546    0.088110    0.088110  105728000
# 1980-12-17    0.090291    0.090727    0.090291    0.090291   86441600
# 1980-12-18    0.092908    0.093345    0.092908    0.092908   73449600
# ...                ...         ...         ...         ...        ...
# 2022-03-14  151.449997  154.119995  150.100006  150.619995  108732100
# 2022-03-15  150.899994  155.570007  150.380005  155.089996   92964300
# 2022-03-16  157.050003  160.000000  154.460007  159.589996  102300200
# 2022-03-17  158.610001  161.000000  157.630005  160.619995   75615400
# 2022-03-18  160.509995  164.479996  159.759995  163.979996  123351200
#
#             Dividends  Stock Splits
# Date
# 1980-12-12        0.0           0.0
# 1980-12-15        0.0           0.0
# ...

# %%
yf.download("CPNG")
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Open       High        Low      Close  Adj Close    Volume
# Date
# 2021-03-11  63.500000  69.000000  49.250000  49.250000  49.250000  91584100
# 2021-03-12  52.540001  52.759998  46.250000  48.470001  48.470001  30521000
# 2021-03-15  50.130001  51.849998  49.020000  50.450001  50.450001  17387800
# 2021-03-16  50.590000  50.770000  46.700001  47.130001  47.130001  14552400
# 2021-03-17  46.000000  46.900002  43.189999  43.290001  43.290001  15251100
# ...               ...        ...        ...        ...        ...       ...
# 2022-03-14  17.040001  17.488001  15.920000  16.120001  16.120001  17621600
# 2022-03-15  16.070000  16.959999  15.275000  15.450000  15.450000  30197600
# 2022-03-16  16.000000  18.120001  15.820000  18.090000  18.090000  40631500
# 2022-03-17  17.680000  19.245001  17.400000  19.200001  19.200001  19894800
# ...

# %%
cpng = yf.Ticker('CPNG')

# %%
cpng.info
# Out:
# {'zip': '05510',
#  'sector': 'Consumer Cyclical',
#  'fullTimeEmployees': 68000,
#  'longBusinessSummary': 'Coupang, Inc. owns and operates in e-commerce business through its mobile applications and Internet websites primarily in South Korea. It operates through two segments, Product Commerce and Growth Initiatives. The company sells various products and services in the categories of home goods and dÃ©cor products, apparel, beauty products, fresh food and groceries, sporting goods, electronics, and everyday consumables, as well as travel, and restaurant order and delivery services. It also performs operations and support services in China, Singapore, Japan, Taiwan, and the United States. Coupang, Inc. was incorporated in 2010 and is headquartered in Seoul, South Korea.',
#  'city': 'Seoul',
#  'phone': '82 2 6150 5422',
#  'country': 'South Korea',
#  'companyOfficers': [],
#  'website': 'https://www.coupang.com',
#  'maxAge': 1,
#  'address1': 'Tower 730,570',
# ...

# %%
import pandas as pd
result = cpng.info

# %%
pd.DataFrame(result)
# Out:
# Empty DataFrame
# ...

# %%
import pyupbit as upbit

# %%
upbit.get_tickers(fiat="KRW")
# Out:
# ['KRW-BTC',
#  'KRW-ETH',
#  'KRW-NEO',
#  'KRW-MTL',
#  'KRW-LTC',
#  'KRW-XRP',
#  'KRW-ETC',
#  'KRW-OMG',
#  'KRW-SNT',
#  'KRW-WAVES',
#  'KRW-XEM',
#  'KRW-QTUM',
#  'KRW-LSK',
#  'KRW-STEEM',
#  'KRW-XLM',
#  'KRW-ARDR',
#  'KRW-ARK',
#  'KRW-STORJ',
#  'KRW-GRS',
#  'KRW-REP',
#  'KRW-ADA',
#  'KRW-SBD',
#  'KRW-POWR',
#  'KRW-BTG',
#  'KRW-ICX',
#  'KRW-EOS',
#  'KRW-TRX',
#  'KRW-SC',
#  'KRW-ONT',
#  'KRW-ZIL',
#  'KRW-POLY',
#  'KRW-ZRX',
#  'KRW-LOOM',
#  'KRW-BCH',
#  'KRW-BAT',
#  'KRW-IOST',
#  'KRW-RFR',
#  'KRW-CVC',
#  'KRW-IQ',
#  'KRW-IOTA',
#  'KRW-MFT',
#  'KRW-ONG',
#  'KRW-GAS',
#  'KRW-UPP',
#  'KRW-ELF',
#  'KRW-KNC',
#  'KRW-BSV',
#  'KRW-THETA',
#  'KRW-QKC',
#  'KRW-BTT',
#  'KRW-MOC',
#  'KRW-ENJ',
#  'KRW-TFUEL',
#  'KRW-MANA',
#  'KRW-ANKR',
#  'KRW-AERGO',
#  'KRW-ATOM',
#  'KRW-TT',
#  'KRW-CRE',
#  'KRW-MBL',
#  'KRW-WAXP',
#  'KRW-HBAR',
#  'KRW-MED',
#  'KRW-MLK',
#  'KRW-STPT',
#  'KRW-ORBS',
#  'KRW-VET',
#  'KRW-CHZ',
#  'KRW-STMX',
# ...

# %%
upbit.get_current_price(["KRW-BTC", "KRW-ETH"])
# Out:
# {'KRW-BTC': 50029000.0, 'KRW-ETH': 3480000.0}

# %%
ticker = "KRW-BTC"
interval = 'minute1'
to = "2022-01-01 00:00"
count = 100
upbit.get_ohlcv(ticker=ticker, interval=interval, to=to, count=count)
# Out:
#                            open        high         low       close    volume  \
# 2021-12-31 22:20:00  58249000.0  58282000.0  58245000.0  58266000.0  2.009468
# 2021-12-31 22:21:00  58266000.0  58282000.0  58252000.0  58265000.0  0.629447
# 2021-12-31 22:22:00  58265000.0  58315000.0  58252000.0  58254000.0  1.310532
# 2021-12-31 22:23:00  58253000.0  58260000.0  58253000.0  58260000.0  1.129435
# 2021-12-31 22:24:00  58260000.0  58260000.0  58254000.0  58259000.0  1.074784
# ...                         ...         ...         ...         ...       ...
# 2021-12-31 23:55:00  58429000.0  58429000.0  58404000.0  58427000.0  0.735981
# 2021-12-31 23:56:00  58427000.0  58437000.0  58426000.0  58437000.0  1.780857
# 2021-12-31 23:57:00  58437000.0  58439000.0  58428000.0  58429000.0  5.769823
# 2021-12-31 23:58:00  58429000.0  58429000.0  58406000.0  58429000.0  1.436200
# 2021-12-31 23:59:00  58429000.0  58438000.0  58400000.0  58412000.0  1.743631
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
y = np.array(upbit.get_ohlcv(ticker=ticker, interval=interval, to=to, count=count)["open"])

# %%
plt.plot(y)
plt.show()

# %% [markdown]
# 1. 주식, 코인 데이터를 가지고 데이터의 갯수 1000개 선택
# 2. 데이터를 csv로 변환
# 3. csv를 DB 삽입
# 4. MYSQL QUERY 데이터를 받아오는데 (Module 생성, Class로 구현)
# 5. 주식의 기준-> 시가, 종가, 고가, 저가 수수점 2번째 자리까지 유지반올림
# 6. 코인의 기준 -> 볼륨 소수점 2번째 자리까지 유지 반올림.
# 7. 주식 기준 Nan 값 존재 시작되는 지점을 시가로 변환
# 8. 컬럼을 하나 추가 등락폭(종가-시가의 값)을 삽입
# 9. 컬럼을 하나 추가(등락폭/시가*100)퍼센트를 삽입
# 10. 데이터의 시각화 -> 시가/종가/등락폭/볼륨 그래프4개를 한 plot표시

# %%
ticker = "KRW-BTC"
interval = 'minute15'
count = 1000
btc = upbit.get_ohlcv(ticker=ticker, interval=interval, count=count)
btc
# Out:
#                            open        high         low       close  \
# 2022-03-11 04:45:00  48791000.0  49150000.0  48753000.0  48998000.0
# 2022-03-11 05:00:00  49020000.0  49021000.0  48875000.0  48980000.0
# 2022-03-11 05:15:00  48980000.0  48993000.0  48854000.0  48940000.0
# 2022-03-11 05:30:00  48938000.0  49094000.0  48904000.0  49088000.0
# 2022-03-11 05:45:00  49086000.0  49260000.0  49002000.0  49233000.0
# ...                         ...         ...         ...         ...
# 2022-03-21 13:30:00  50035000.0  50040000.0  49993000.0  50030000.0
# 2022-03-21 13:45:00  50030000.0  50100000.0  50025000.0  50050000.0
# 2022-03-21 14:00:00  50050000.0  50093000.0  50000000.0  50059000.0
# 2022-03-21 14:15:00  50061000.0  50088000.0  50034000.0  50082000.0
# 2022-03-21 14:30:00  50082000.0  50114000.0  50051000.0  50112000.0
#
#                         volume         value
# 2022-03-11 04:45:00  36.941400  1.808888e+09
# 2022-03-11 05:00:00  23.321799  1.141052e+09
# ...

# %%
import csv

# %%
csv_Cursor = open('./btc.csv', 'w', newline='')
wr = csv.writer(csv_Cursor)
for idx in result:
    wr.writerow(btc)

csv_Cursor.close()

# %%
df_btc = pd.DataFrame(btc)

# %%
df_btc.to_csv("./btc.csv")

# %%
import mod_sql

# %%
_db = mod_sql.Database()
sql = "SELECT *FROM btc"
result = _db._executeAll(sql)
dt = pd.DataFrame(result)
dt
# Out:
#         MyUnknownColumn        open        high         low       close  \
# 0   2022-03-11 04:45:00  48791000.0  49150000.0  48753000.0  48998000.0
# 1   2022-03-11 05:00:00  49020000.0  49021000.0  48875000.0  48980000.0
# 2   2022-03-11 05:15:00  48980000.0  48993000.0  48854000.0  48940000.0
# 3   2022-03-11 05:30:00  48938000.0  49094000.0  48904000.0  49088000.0
# 4   2022-03-11 05:45:00  49086000.0  49260000.0  49002000.0  49233000.0
# ..                  ...         ...         ...         ...         ...
# 995 2022-03-21 13:30:00  50035000.0  50040000.0  49993000.0  50030000.0
# 996 2022-03-21 13:45:00  50030000.0  50100000.0  50025000.0  50050000.0
# 997 2022-03-21 14:00:00  50050000.0  50093000.0  50000000.0  50059000.0
# 998 2022-03-21 14:15:00  50061000.0  50088000.0  50034000.0  50082000.0
# 999 2022-03-21 14:30:00  50082000.0  50114000.0  50051000.0  50112000.0
#
#         volume         value
# 0    36.941400  1.808888e+09
# 1    23.321799  1.141052e+09
# ...

# %%
dt_1 = dt
dt_1.columns = ["날짜", "시가", "고가", "저가", "종가", "거래량", "가치"]

# %%
dt_1
# Out:
#                      날짜          시가          고가          저가          종가  \
# 0   2022-03-11 04:45:00  48791000.0  49150000.0  48753000.0  48998000.0
# 1   2022-03-11 05:00:00  49020000.0  49021000.0  48875000.0  48980000.0
# 2   2022-03-11 05:15:00  48980000.0  48993000.0  48854000.0  48940000.0
# 3   2022-03-11 05:30:00  48938000.0  49094000.0  48904000.0  49088000.0
# 4   2022-03-11 05:45:00  49086000.0  49260000.0  49002000.0  49233000.0
# ..                  ...         ...         ...         ...         ...
# 995 2022-03-21 13:30:00  50035000.0  50040000.0  49993000.0  50030000.0
# 996 2022-03-21 13:45:00  50030000.0  50100000.0  50025000.0  50050000.0
# 997 2022-03-21 14:00:00  50050000.0  50093000.0  50000000.0  50059000.0
# 998 2022-03-21 14:15:00  50061000.0  50088000.0  50034000.0  50082000.0
# 999 2022-03-21 14:30:00  50082000.0  50114000.0  50051000.0  50112000.0
#
#            거래량            가치
# 0    36.941400  1.808888e+09
# 1    23.321799  1.141052e+09
# ...

# %%
dt_2 = dt_1
dt_2["거래량"] = dt_2["거래량"].round(2)
dt_2
# Out:
#                      날짜          시가          고가          저가          종가  \
# 0   2022-03-11 04:45:00  48791000.0  49150000.0  48753000.0  48998000.0
# 1   2022-03-11 05:00:00  49020000.0  49021000.0  48875000.0  48980000.0
# 2   2022-03-11 05:15:00  48980000.0  48993000.0  48854000.0  48940000.0
# 3   2022-03-11 05:30:00  48938000.0  49094000.0  48904000.0  49088000.0
# 4   2022-03-11 05:45:00  49086000.0  49260000.0  49002000.0  49233000.0
# ..                  ...         ...         ...         ...         ...
# 995 2022-03-21 13:30:00  50035000.0  50040000.0  49993000.0  50030000.0
# 996 2022-03-21 13:45:00  50030000.0  50100000.0  50025000.0  50050000.0
# 997 2022-03-21 14:00:00  50050000.0  50093000.0  50000000.0  50059000.0
# 998 2022-03-21 14:15:00  50061000.0  50088000.0  50034000.0  50082000.0
# 999 2022-03-21 14:30:00  50082000.0  50114000.0  50051000.0  50112000.0
#
#        거래량            가치
# 0    36.94  1.808888e+09
# 1    23.32  1.141052e+09
# ...

# %%
dt_2["등락폭"] = dt_2["시가"]-dt_2["종가"]
dt_2
# Out:
#                      날짜          시가          고가          저가          종가  \
# 0   2022-03-11 04:45:00  48791000.0  49150000.0  48753000.0  48998000.0
# 1   2022-03-11 05:00:00  49020000.0  49021000.0  48875000.0  48980000.0
# 2   2022-03-11 05:15:00  48980000.0  48993000.0  48854000.0  48940000.0
# 3   2022-03-11 05:30:00  48938000.0  49094000.0  48904000.0  49088000.0
# 4   2022-03-11 05:45:00  49086000.0  49260000.0  49002000.0  49233000.0
# ..                  ...         ...         ...         ...         ...
# 995 2022-03-21 13:30:00  50035000.0  50040000.0  49993000.0  50030000.0
# 996 2022-03-21 13:45:00  50030000.0  50100000.0  50025000.0  50050000.0
# 997 2022-03-21 14:00:00  50050000.0  50093000.0  50000000.0  50059000.0
# 998 2022-03-21 14:15:00  50061000.0  50088000.0  50034000.0  50082000.0
# 999 2022-03-21 14:30:00  50082000.0  50114000.0  50051000.0  50112000.0
#
#        거래량            가치       등락폭
# 0    36.94  1.808888e+09 -207000.0
# ...

# %%
x = dt_2["날짜"]

# %%
plt.figure(figsize=(10,10)).set_facecolor('w')
plt.subplots_adjust(wspace= 0.3,hspace= 0.3)

plt.subplot(2,2,1).set_facecolor("bisque")
plt.plot(x, dt_2["시가"],'r')
plt.title("open")

plt.subplot(2,2,2).set_facecolor("bisque")
plt.plot(x, dt_2["종가"],'g')
plt.title("close")

plt.subplot(2,2,3).set_facecolor("bisque")
plt.plot(x, dt_2["등락폭"],'y')
plt.title("diff")

plt.subplot(2,2,4).set_facecolor("bisque")
plt.plot(x, dt_2["거래량"],'k')
plt.title("volume")


plt.show()
